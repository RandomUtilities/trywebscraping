# %%
import requests
from bs4 import BeautifulSoup

# %%
results = requests.get("https://en.wikipedia.org/wiki/Nintendo_Switch")

# %%
results.status_code
# Out:
# 200

# %%
src = results.content
soup = BeautifulSoup(src)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Nintendo Switch - Wikipedia</title>
# ...
